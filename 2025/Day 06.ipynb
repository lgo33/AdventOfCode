# %%
import os
os.environ['AOC_SESSION'] = '53616c7465645f5fff342ea51d49e23402683c410592072d5487798e3d888065a12dfdfa0cfeaf85aa08c4f9628b97149f851b24e02d0bb1c19821c2f480b284'

# %%
import numpy as np
from functools import cache, reduce
import operator as op

# %%
import aocd
from aocd.models import Puzzle
day = 6
year = 2025
puzzle = Puzzle(year=year, day=day)
# data = aocd.get_data(day=day, year=year)
with open('./data/input_{:02d}'.format(day), 'w') as fh:
    fh.write(puzzle.input_data)

# %%
test_data = """123 328  51 64 
 45 64  387 23 
  6 98  215 314
*   +   *   +  """
data_test = test_data.splitlines()

# %%
def parse(line):
    parts = line.split()
    return [int(x) for x in parts]

# %%
data = puzzle.input_data.splitlines()
len(data), data[:10]
# Out:
# (5,
# ...

# %%
# dat = data_test
dat = data

num = [parse(line) for line in dat[:-1]]
operators = dat[-1].split()

tot = 0
for i, row in enumerate(zip(*num)):
    tot += reduce( {'+': op.add, '*': op.mul}[operators[i]], row)
tot
# Out:
# 5316572080628

# %%
puzzle.answer_a = str(tot)
# Out:
# That's the right answer!  You are one gold star closer to decorating the North Pole. [Continue to Part Two]

# %% [markdown]
# # Part 2

# %%
# dat = data_test
dat = data

numbers = dat[:-1]
operators = dat[-1].split()


flipped = np.array([list(line)+[' '] for line in numbers]).T

n = 0
tot = 0
cur = []
for line in flipped:
    val = ''.join(line).strip()
    if not val:
        print(operators[n], cur)
        tot += reduce( {'+': op.add, '*': op.mul}[operators[n]], cur)
        cur = []
        n += 1
    else:
        cur.append(int(val))
tot
# Out:
# + [3256, 6845, 6944, 371]
# * [5, 2282, 7395]
# + [2139, 2581, 8679]
# * [6785, 1547, 762]
# + [73, 5343, 3595]
# * [1434, 4686, 85]
# + [1882, 4445, 6428, 638]
# + [85, 412, 5545]
# * [97, 1533]
# * [8829, 33]
# * [9516, 2779]
# + [8, 81, 5621]
# * [6627, 4486, 187]
# * [4495, 132]
# + [8152, 2, 3]
# * [9242, 575, 25]
# * [7575, 5675]
# + [2394, 3585, 145, 713]
# + [242, 6485]
# * [4652, 3886]
# * [234, 2862, 9636]
# + [4993, 7511, 85]
# * [6462, 3159, 327]
# + [528, 387, 4535, 7527]
# * [1189, 9599, 2599]
# + [6659, 4424, 51, 9]
# * [5619, 94, 51]
# + [4474, 984, 69]
# * [6197, 4926, 4984]
# * [1478, 41]
# * [7128, 4774]
# + [1514, 1883, 9965]
# * [9974, 4929]
# + [974, 9988]
# + [34, 181, 1564]
# + [5255, 5512]
# * [82, 751, 7334]
# + [639, 2246]
# + [1163, 2743, 6447, 9672]
# + [1351, 3252, 38]
# * [1698, 24, 83]
# * [3237, 6194, 8578]
# * [7525, 5891]
# * [139, 8857]
# * [3779, 2479]
# + [6868, 6459, 494]
# * [18, 5963]
# * [98, 4943]
# * [54, 7846]
# + [7631, 6593, 634, 589]
# ...

# %%
puzzle.answer_b = str(tot)
# Out:
# That's the right answer!  You are one gold star closer to decorating the North Pole.You have completed Day 6! You can [Shareon
#   Bluesky
# Twitter
# Mastodon] this victory or [Return to Your Advent Calendar].

# %%
dat = data_test
numbers = dat[:-1]

list(zip(*[list(line)+[' '] for line in numbers]))
# Out:
# [('1', ' ', ' '),
#  ('2', '4', ' '),
#  ('3', '5', '6'),
#  (' ', ' ', ' '),
#  ('3', '6', '9'),
#  ('2', '4', '8'),
#  ('8', ' ', ' '),
#  (' ', ' ', ' '),
#  (' ', '3', '2'),
#  ('5', '8', '1'),
#  ('1', '7', '5'),
#  (' ', ' ', ' '),
#  ('6', '2', '3'),
#  ('4', '3', '1'),
#  (' ', ' ', '4'),
#  (' ', ' ', ' ')]

# %%
# dat = data_test
dat = data

numbers = dat[:-1]
operators = dat[-1].split()


flipped = zip(*[list(line)+[' '] for line in numbers])

n = 0
tot = 0
cur = []
for line in flipped:
    val = ''.join(line).strip()
    if not val:
        print(operators[n], cur)
        tot += reduce( {'+': op.add, '*': op.mul}[operators[n]], cur)
        cur = []
        n += 1
    else:
        cur.append(int(val))
tot
# Out:
# + [3256, 6845, 6944, 371]
# * [5, 2282, 7395]
# + [2139, 2581, 8679]
# * [6785, 1547, 762]
# + [73, 5343, 3595]
# * [1434, 4686, 85]
# + [1882, 4445, 6428, 638]
# + [85, 412, 5545]
# * [97, 1533]
# * [8829, 33]
# * [9516, 2779]
# + [8, 81, 5621]
# * [6627, 4486, 187]
# * [4495, 132]
# + [8152, 2, 3]
# * [9242, 575, 25]
# * [7575, 5675]
# + [2394, 3585, 145, 713]
# + [242, 6485]
# * [4652, 3886]
# * [234, 2862, 9636]
# + [4993, 7511, 85]
# * [6462, 3159, 327]
# + [528, 387, 4535, 7527]
# * [1189, 9599, 2599]
# + [6659, 4424, 51, 9]
# * [5619, 94, 51]
# + [4474, 984, 69]
# * [6197, 4926, 4984]
# * [1478, 41]
# * [7128, 4774]
# + [1514, 1883, 9965]
# * [9974, 4929]
# + [974, 9988]
# + [34, 181, 1564]
# + [5255, 5512]
# * [82, 751, 7334]
# + [639, 2246]
# + [1163, 2743, 6447, 9672]
# + [1351, 3252, 38]
# * [1698, 24, 83]
# * [3237, 6194, 8578]
# * [7525, 5891]
# * [139, 8857]
# * [3779, 2479]
# + [6868, 6459, 494]
# * [18, 5963]
# * [98, 4943]
# * [54, 7846]
# + [7631, 6593, 634, 589]
# ...
