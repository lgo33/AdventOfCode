# %%
import aocd
from aocd.models import Puzzle
day = 24
year = 2021
puzzle = Puzzle(year=year, day=day)
# data = aocd.get_data(day=day, year=year)
with open('./data/input_{:02d}'.format(day), 'w') as fh:
    fh.write(puzzle.input_data)

# %%
data = puzzle.input_data.splitlines()
len(data), data[:10]
# Out:
# (252,
#  ['inp w',
#   'mul x 0',
#   'add x z',
#   'mod x 26',
#   'div z 1',
#   'add x 13',
#   'eql x w',
#   'eql x 0',
#   'mul y 0',
#   'add y 25'])

# %%
test_data = """inp w
add z w
mod z 2
div w 2
add y w
mod y 2
div w 2
add x w
mod x 2
div w 2
mod w 2""".splitlines()

# %%
class ALU():
    def __init__(self, buffer=None, instructions=None, debug=False):
        self.w = 0
        self.x = 0
        self.y = 0
        self.z = 0
        if buffer is not None:
            self.buffer = buffer
        else:
            self.buffer = []
        self.loc = 0
        if instructions is not None:
            self.read(instructions)
        self.functions = {
            'inp': self.store,
            'add': self.add,
            'mul': self.mul,
            'div': self.div,
            'mod': self.mod,
            'eql': self.eql
        }
        self.debug = debug
        
    def reset(self):
        self.w = 0
        self.x = 0
        self.y = 0
        self.z = 0
        self.loc = 0
        
    def read(self, instructions):
        self.instructions = list(map(lambda x: x.split(' '), instructions))
    
    def run(self):
        self.reset()
        while self.loc < len(self.instructions):
            self.execute(self.instructions[self.loc])
            self.loc += 1
            
    def execute(self, instruction):
        cmd, *args = instruction
        if cmd in self.functions:
            self.functions[cmd](*args)
            if self.debug:
                print(cmd, args , " \t", self.__repr__())
            
    
    def get_val(self, val):
        if val in ['w', 'x', 'y', 'z']:
            return self.__dict__[val]
        return int(val)
    
    def store(self, variable):
        self.__dict__[variable] = int(self.buffer.pop(0))
    
    def add(self, a, b):
        self.__dict__[a] = self.__dict__[a] + self.get_val(b)
    
    def mul(self, a, b):
        self.__dict__[a] = self.__dict__[a] * self.get_val(b)
    
    def div(self, a, b):
        self.__dict__[a] = int(self.__dict__[a] / self.get_val(b))
    
    def mod(self, a, b):
        self.__dict__[a] = self.__dict__[a] % self.get_val(b)
        
    def eql(self, a, b):
        self.__dict__[a] = int(self.__dict__[a] == self.get_val(b))
        
    def __repr__(self):
        return 'w={} | x={} | y={} | z={} | z={}'.format(self.w, self.x, self.y, self.z, np.base_repr(self.z, base=26))

# %%
alu = ALU(instructions=test_data, buffer=[123])

# %%
alu.instructions
# Out:
# [['inp', 'w'],
#  ['add', 'z', 'w'],
#  ['mod', 'z', '2'],
#  ['div', 'w', '2'],
#  ['add', 'y', 'w'],
#  ['mod', 'y', '2'],
#  ['div', 'w', '2'],
#  ['add', 'x', 'w'],
#  ['mod', 'x', '2'],
#  ['div', 'w', '2'],
#  ['mod', 'w', '2']]

# %%
alu.buffer=[8]
alu.run()
alu
# Out:
# w=1 | x=0 | y=0 | z=0

# %%
from itertools import combinations, product, combinations_with_replacement

# %%
# %%time
cnt = 0
for monad in product(range(9,0,-1), repeat=14):
    
    alu = ALU(instructions=data, buffer=list(monad))
    alu.run()
              
    if (alu.z == 0):
        print(monad)
        break
        
    for i in range(6):
        if monad[-i] != 9:
            break
    else:
        print(monad)
        cnt += 1
        if cnt == 2:
            break
# Out:
# (9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9)
# (9, 9, 9, 9, 9, 9, 9, 9, 8, 9, 9, 9, 9, 9)
# CPU times: user 39.9 s, sys: 67.1 ms, total: 40 s
# Wall time: 40 s

# %%
monad = (9, 9, 6, 9, 1, 8, 9, 1, 9, 7, 9, 9, 3, 8)
print(monad)
alu = ALU(instructions=data, buffer=list(monad), debug=True)
alu.run()
alu
# Out:
# (9, 9, 6, 9, 1, 8, 9, 1, 9, 7, 9, 9, 3, 8)
# inp ['w']  	 w=9 | x=0 | y=0 | z=0 | z=0
# mul ['x', '0']  	 w=9 | x=0 | y=0 | z=0 | z=0
# add ['x', 'z']  	 w=9 | x=0 | y=0 | z=0 | z=0
# mod ['x', '26']  	 w=9 | x=0 | y=0 | z=0 | z=0
# div ['z', '1']  	 w=9 | x=0 | y=0 | z=0 | z=0
# add ['x', '13']  	 w=9 | x=13 | y=0 | z=0 | z=0
# eql ['x', 'w']  	 w=9 | x=0 | y=0 | z=0 | z=0
# eql ['x', '0']  	 w=9 | x=1 | y=0 | z=0 | z=0
# mul ['y', '0']  	 w=9 | x=1 | y=0 | z=0 | z=0
# add ['y', '25']  	 w=9 | x=1 | y=25 | z=0 | z=0
# mul ['y', 'x']  	 w=9 | x=1 | y=25 | z=0 | z=0
# add ['y', '1']  	 w=9 | x=1 | y=26 | z=0 | z=0
# mul ['z', 'y']  	 w=9 | x=1 | y=26 | z=0 | z=0
# mul ['y', '0']  	 w=9 | x=1 | y=0 | z=0 | z=0
# add ['y', 'w']  	 w=9 | x=1 | y=9 | z=0 | z=0
# add ['y', '0']  	 w=9 | x=1 | y=9 | z=0 | z=0
# mul ['y', 'x']  	 w=9 | x=1 | y=9 | z=0 | z=0
# add ['z', 'y']  	 w=9 | x=1 | y=9 | z=9 | z=9
# inp ['w']  	 w=9 | x=1 | y=9 | z=9 | z=9
# mul ['x', '0']  	 w=9 | x=0 | y=9 | z=9 | z=9
# add ['x', 'z']  	 w=9 | x=9 | y=9 | z=9 | z=9
# mod ['x', '26']  	 w=9 | x=9 | y=9 | z=9 | z=9
# div ['z', '1']  	 w=9 | x=9 | y=9 | z=9 | z=9
# add ['x', '11']  	 w=9 | x=20 | y=9 | z=9 | z=9
# eql ['x', 'w']  	 w=9 | x=0 | y=9 | z=9 | z=9
# eql ['x', '0']  	 w=9 | x=1 | y=9 | z=9 | z=9
# mul ['y', '0']  	 w=9 | x=1 | y=0 | z=9 | z=9
# add ['y', '25']  	 w=9 | x=1 | y=25 | z=9 | z=9
# mul ['y', 'x']  	 w=9 | x=1 | y=25 | z=9 | z=9
# add ['y', '1']  	 w=9 | x=1 | y=26 | z=9 | z=9
# mul ['z', 'y']  	 w=9 | x=1 | y=26 | z=234 | z=90
# mul ['y', '0']  	 w=9 | x=1 | y=0 | z=234 | z=90
# add ['y', 'w']  	 w=9 | x=1 | y=9 | z=234 | z=90
# add ['y', '3']  	 w=9 | x=1 | y=12 | z=234 | z=90
# mul ['y', 'x']  	 w=9 | x=1 | y=12 | z=234 | z=90
# add ['z', 'y']  	 w=9 | x=1 | y=12 | z=246 | z=9C
# inp ['w']  	 w=6 | x=1 | y=12 | z=246 | z=9C
# mul ['x', '0']  	 w=6 | x=0 | y=12 | z=246 | z=9C
# add ['x', 'z']  	 w=6 | x=246 | y=12 | z=246 | z=9C
# mod ['x', '26']  	 w=6 | x=12 | y=12 | z=246 | z=9C
# div ['z', '1']  	 w=6 | x=12 | y=12 | z=246 | z=9C
# add ['x', '14']  	 w=6 | x=26 | y=12 | z=246 | z=9C
# eql ['x', 'w']  	 w=6 | x=0 | y=12 | z=246 | z=9C
# eql ['x', '0']  	 w=6 | x=1 | y=12 | z=246 | z=9C
# mul ['y', '0']  	 w=6 | x=1 | y=0 | z=246 | z=9C
# add ['y', '25']  	 w=6 | x=1 | y=25 | z=246 | z=9C
# mul ['y', 'x']  	 w=6 | x=1 | y=25 | z=246 | z=9C
# add ['y', '1']  	 w=6 | x=1 | y=26 | z=246 | z=9C
# mul ['z', 'y']  	 w=6 | x=1 | y=26 | z=6396 | z=9C0
# mul ['y', '0']  	 w=6 | x=1 | y=0 | z=6396 | z=9C0
# add ['y', 'w']  	 w=6 | x=1 | y=6 | z=6396 | z=9C0
# add ['y', '8']  	 w=6 | x=1 | y=14 | z=6396 | z=9C0
# mul ['y', 'x']  	 w=6 | x=1 | y=14 | z=6396 | z=9C0
# add ['z', 'y']  	 w=6 | x=1 | y=14 | z=6410 | z=9CE
# inp ['w']  	 w=9 | x=1 | y=14 | z=6410 | z=9CE
# mul ['x', '0']  	 w=9 | x=0 | y=14 | z=6410 | z=9CE
# add ['x', 'z']  	 w=9 | x=6410 | y=14 | z=6410 | z=9CE
# mod ['x', '26']  	 w=9 | x=14 | y=14 | z=6410 | z=9CE
# div ['z', '26']  	 w=9 | x=14 | y=14 | z=246 | z=9C
# add ['x', '-5']  	 w=9 | x=9 | y=14 | z=246 | z=9C
# eql ['x', 'w']  	 w=9 | x=1 | y=14 | z=246 | z=9C
# eql ['x', '0']  	 w=9 | x=0 | y=14 | z=246 | z=9C
# mul ['y', '0']  	 w=9 | x=0 | y=0 | z=246 | z=9C
# add ['y', '25']  	 w=9 | x=0 | y=25 | z=246 | z=9C
# mul ['y', 'x']  	 w=9 | x=0 | y=0 | z=246 | z=9C
# add ['y', '1']  	 w=9 | x=0 | y=1 | z=246 | z=9C
# mul ['z', 'y']  	 w=9 | x=0 | y=1 | z=246 | z=9C
# mul ['y', '0']  	 w=9 | x=0 | y=0 | z=246 | z=9C
# add ['y', 'w']  	 w=9 | x=0 | y=9 | z=246 | z=9C
# add ['y', '5']  	 w=9 | x=0 | y=14 | z=246 | z=9C
# mul ['y', 'x']  	 w=9 | x=0 | y=0 | z=246 | z=9C
# add ['z', 'y']  	 w=9 | x=0 | y=0 | z=246 | z=9C
# inp ['w']  	 w=1 | x=0 | y=0 | z=246 | z=9C
# mul ['x', '0']  	 w=1 | x=0 | y=0 | z=246 | z=9C
# add ['x', 'z']  	 w=1 | x=246 | y=0 | z=246 | z=9C
# mod ['x', '26']  	 w=1 | x=12 | y=0 | z=246 | z=9C
# div ['z', '1']  	 w=1 | x=12 | y=0 | z=246 | z=9C
# add ['x', '14']  	 w=1 | x=26 | y=0 | z=246 | z=9C
# add ['y', 'w']  	 w=8 | x=0 | y=8 | z=0 | z=0
# add ['y', '15']  	 w=8 | x=0 | y=23 | z=0 | z=0
# mul ['y', 'x']  	 w=8 | x=0 | y=0 | z=0 | z=0
# add ['z', 'y']  	 w=8 | x=0 | y=0 | z=0 | z=0
# w=8 | x=0 | y=0 | z=0 | z=0

# %%
print (monad)
print ("".join([str(m) for m in monad]))
# Out:
# (9, 9, 6, 9, 1, 8, 9, 1, 9, 7, 9, 9, 3, 8)
# 99691891979938

# %%
puzzle.answer_a = "".join([str(m) for m in monad])
# Out:
# That's the right answer!  You are one gold star closer to finding the sleigh keys. [Continue to Part Two]

# %%
monad = (2, 7, 1, 4, 1, 1, 9, 1, 2, 1, 3, 9, 1, 1)
print(monad)
alu = ALU(instructions=data, buffer=list(monad), debug=True)
alu.run()
alu
# Out:
# (2, 7, 1, 4, 1, 1, 9, 1, 2, 1, 3, 9, 1, 1)
# inp ['w']  	 w=2 | x=0 | y=0 | z=0
# mul ['x', '0']  	 w=2 | x=0 | y=0 | z=0
# add ['x', 'z']  	 w=2 | x=0 | y=0 | z=0
# mod ['x', '26']  	 w=2 | x=0 | y=0 | z=0
# div ['z', '1']  	 w=2 | x=0 | y=0 | z=0
# add ['x', '13']  	 w=2 | x=13 | y=0 | z=0
# eql ['x', 'w']  	 w=2 | x=0 | y=0 | z=0
# eql ['x', '0']  	 w=2 | x=1 | y=0 | z=0
# mul ['y', '0']  	 w=2 | x=1 | y=0 | z=0
# add ['y', '25']  	 w=2 | x=1 | y=25 | z=0
# mul ['y', 'x']  	 w=2 | x=1 | y=25 | z=0
# add ['y', '1']  	 w=2 | x=1 | y=26 | z=0
# mul ['z', 'y']  	 w=2 | x=1 | y=26 | z=0
# mul ['y', '0']  	 w=2 | x=1 | y=0 | z=0
# add ['y', 'w']  	 w=2 | x=1 | y=2 | z=0
# add ['y', '0']  	 w=2 | x=1 | y=2 | z=0
# mul ['y', 'x']  	 w=2 | x=1 | y=2 | z=0
# add ['z', 'y']  	 w=2 | x=1 | y=2 | z=2
# inp ['w']  	 w=7 | x=1 | y=2 | z=2
# mul ['x', '0']  	 w=7 | x=0 | y=2 | z=2
# add ['x', 'z']  	 w=7 | x=2 | y=2 | z=2
# mod ['x', '26']  	 w=7 | x=2 | y=2 | z=2
# div ['z', '1']  	 w=7 | x=2 | y=2 | z=2
# add ['x', '11']  	 w=7 | x=13 | y=2 | z=2
# eql ['x', 'w']  	 w=7 | x=0 | y=2 | z=2
# eql ['x', '0']  	 w=7 | x=1 | y=2 | z=2
# mul ['y', '0']  	 w=7 | x=1 | y=0 | z=2
# add ['y', '25']  	 w=7 | x=1 | y=25 | z=2
# mul ['y', 'x']  	 w=7 | x=1 | y=25 | z=2
# add ['y', '1']  	 w=7 | x=1 | y=26 | z=2
# mul ['z', 'y']  	 w=7 | x=1 | y=26 | z=52
# mul ['y', '0']  	 w=7 | x=1 | y=0 | z=52
# add ['y', 'w']  	 w=7 | x=1 | y=7 | z=52
# add ['y', '3']  	 w=7 | x=1 | y=10 | z=52
# mul ['y', 'x']  	 w=7 | x=1 | y=10 | z=52
# add ['z', 'y']  	 w=7 | x=1 | y=10 | z=62
# inp ['w']  	 w=1 | x=1 | y=10 | z=62
# mul ['x', '0']  	 w=1 | x=0 | y=10 | z=62
# add ['x', 'z']  	 w=1 | x=62 | y=10 | z=62
# mod ['x', '26']  	 w=1 | x=10 | y=10 | z=62
# div ['z', '1']  	 w=1 | x=10 | y=10 | z=62
# add ['x', '14']  	 w=1 | x=24 | y=10 | z=62
# eql ['x', 'w']  	 w=1 | x=0 | y=10 | z=62
# eql ['x', '0']  	 w=1 | x=1 | y=10 | z=62
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=62
# add ['y', '25']  	 w=1 | x=1 | y=25 | z=62
# mul ['y', 'x']  	 w=1 | x=1 | y=25 | z=62
# add ['y', '1']  	 w=1 | x=1 | y=26 | z=62
# mul ['z', 'y']  	 w=1 | x=1 | y=26 | z=1612
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=1612
# add ['y', 'w']  	 w=1 | x=1 | y=1 | z=1612
# add ['y', '8']  	 w=1 | x=1 | y=9 | z=1612
# mul ['y', 'x']  	 w=1 | x=1 | y=9 | z=1612
# add ['z', 'y']  	 w=1 | x=1 | y=9 | z=1621
# inp ['w']  	 w=4 | x=1 | y=9 | z=1621
# mul ['x', '0']  	 w=4 | x=0 | y=9 | z=1621
# add ['x', 'z']  	 w=4 | x=1621 | y=9 | z=1621
# mod ['x', '26']  	 w=4 | x=9 | y=9 | z=1621
# div ['z', '26']  	 w=4 | x=9 | y=9 | z=62
# add ['x', '-5']  	 w=4 | x=4 | y=9 | z=62
# eql ['x', 'w']  	 w=4 | x=1 | y=9 | z=62
# eql ['x', '0']  	 w=4 | x=0 | y=9 | z=62
# mul ['y', '0']  	 w=4 | x=0 | y=0 | z=62
# add ['y', '25']  	 w=4 | x=0 | y=25 | z=62
# mul ['y', 'x']  	 w=4 | x=0 | y=0 | z=62
# add ['y', '1']  	 w=4 | x=0 | y=1 | z=62
# mul ['z', 'y']  	 w=4 | x=0 | y=1 | z=62
# mul ['y', '0']  	 w=4 | x=0 | y=0 | z=62
# add ['y', 'w']  	 w=4 | x=0 | y=4 | z=62
# add ['y', '5']  	 w=4 | x=0 | y=9 | z=62
# mul ['y', 'x']  	 w=4 | x=0 | y=0 | z=62
# add ['z', 'y']  	 w=4 | x=0 | y=0 | z=62
# inp ['w']  	 w=1 | x=0 | y=0 | z=62
# mul ['x', '0']  	 w=1 | x=0 | y=0 | z=62
# add ['x', 'z']  	 w=1 | x=62 | y=0 | z=62
# mod ['x', '26']  	 w=1 | x=10 | y=0 | z=62
# div ['z', '1']  	 w=1 | x=10 | y=0 | z=62
# add ['x', '14']  	 w=1 | x=24 | y=0 | z=62
# eql ['x', 'w']  	 w=1 | x=0 | y=0 | z=62
# eql ['x', '0']  	 w=1 | x=1 | y=0 | z=62
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=62
# add ['y', '25']  	 w=1 | x=1 | y=25 | z=62
# mul ['y', 'x']  	 w=1 | x=1 | y=25 | z=62
# add ['y', '1']  	 w=1 | x=1 | y=26 | z=62
# mul ['z', 'y']  	 w=1 | x=1 | y=26 | z=1612
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=1612
# add ['y', 'w']  	 w=1 | x=1 | y=1 | z=1612
# add ['y', '13']  	 w=1 | x=1 | y=14 | z=1612
# mul ['y', 'x']  	 w=1 | x=1 | y=14 | z=1612
# add ['z', 'y']  	 w=1 | x=1 | y=14 | z=1626
# inp ['w']  	 w=1 | x=1 | y=14 | z=1626
# mul ['x', '0']  	 w=1 | x=0 | y=14 | z=1626
# add ['x', 'z']  	 w=1 | x=1626 | y=14 | z=1626
# mod ['x', '26']  	 w=1 | x=14 | y=14 | z=1626
# div ['z', '1']  	 w=1 | x=14 | y=14 | z=1626
# add ['x', '10']  	 w=1 | x=24 | y=14 | z=1626
# eql ['x', 'w']  	 w=1 | x=0 | y=14 | z=1626
# eql ['x', '0']  	 w=1 | x=1 | y=14 | z=1626
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=1626
# add ['y', '25']  	 w=1 | x=1 | y=25 | z=1626
# mul ['y', 'x']  	 w=1 | x=1 | y=25 | z=1626
# add ['y', '1']  	 w=1 | x=1 | y=26 | z=1626
# mul ['z', 'y']  	 w=1 | x=1 | y=26 | z=42276
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=42276
# add ['y', 'w']  	 w=1 | x=1 | y=1 | z=42276
# add ['y', '9']  	 w=1 | x=1 | y=10 | z=42276
# mul ['y', 'x']  	 w=1 | x=1 | y=10 | z=42276
# add ['z', 'y']  	 w=1 | x=1 | y=10 | z=42286
# inp ['w']  	 w=9 | x=1 | y=10 | z=42286
# mul ['x', '0']  	 w=9 | x=0 | y=10 | z=42286
# add ['x', 'z']  	 w=9 | x=42286 | y=10 | z=42286
# mod ['x', '26']  	 w=9 | x=10 | y=10 | z=42286
# div ['z', '1']  	 w=9 | x=10 | y=10 | z=42286
# add ['x', '12']  	 w=9 | x=22 | y=10 | z=42286
# eql ['x', 'w']  	 w=9 | x=0 | y=10 | z=42286
# eql ['x', '0']  	 w=9 | x=1 | y=10 | z=42286
# mul ['y', '0']  	 w=9 | x=1 | y=0 | z=42286
# add ['y', '25']  	 w=9 | x=1 | y=25 | z=42286
# mul ['y', 'x']  	 w=9 | x=1 | y=25 | z=42286
# add ['y', '1']  	 w=9 | x=1 | y=26 | z=42286
# mul ['z', 'y']  	 w=9 | x=1 | y=26 | z=1099436
# mul ['y', '0']  	 w=9 | x=1 | y=0 | z=1099436
# add ['y', 'w']  	 w=9 | x=1 | y=9 | z=1099436
# add ['y', '6']  	 w=9 | x=1 | y=15 | z=1099436
# mul ['y', 'x']  	 w=9 | x=1 | y=15 | z=1099436
# add ['z', 'y']  	 w=9 | x=1 | y=15 | z=1099451
# inp ['w']  	 w=1 | x=1 | y=15 | z=1099451
# mul ['x', '0']  	 w=1 | x=0 | y=15 | z=1099451
# add ['x', 'z']  	 w=1 | x=1099451 | y=15 | z=1099451
# mod ['x', '26']  	 w=1 | x=15 | y=15 | z=1099451
# div ['z', '26']  	 w=1 | x=15 | y=15 | z=42286
# add ['x', '-14']  	 w=1 | x=1 | y=15 | z=42286
# eql ['x', 'w']  	 w=1 | x=1 | y=15 | z=42286
# eql ['x', '0']  	 w=1 | x=0 | y=15 | z=42286
# mul ['y', '0']  	 w=1 | x=0 | y=0 | z=42286
# add ['y', '25']  	 w=1 | x=0 | y=25 | z=42286
# mul ['y', 'x']  	 w=1 | x=0 | y=0 | z=42286
# add ['y', '1']  	 w=1 | x=0 | y=1 | z=42286
# mul ['z', 'y']  	 w=1 | x=0 | y=1 | z=42286
# mul ['y', '0']  	 w=1 | x=0 | y=0 | z=42286
# add ['y', 'w']  	 w=1 | x=0 | y=1 | z=42286
# add ['y', '1']  	 w=1 | x=0 | y=2 | z=42286
# mul ['y', 'x']  	 w=1 | x=0 | y=0 | z=42286
# add ['z', 'y']  	 w=1 | x=0 | y=0 | z=42286
# inp ['w']  	 w=2 | x=0 | y=0 | z=42286
# mul ['x', '0']  	 w=2 | x=0 | y=0 | z=42286
# add ['x', 'z']  	 w=2 | x=42286 | y=0 | z=42286
# mod ['x', '26']  	 w=2 | x=10 | y=0 | z=42286
# div ['z', '26']  	 w=2 | x=10 | y=0 | z=1626
# add ['x', '-8']  	 w=2 | x=2 | y=0 | z=1626
# eql ['x', 'w']  	 w=2 | x=1 | y=0 | z=1626
# eql ['x', '0']  	 w=2 | x=0 | y=0 | z=1626
# mul ['y', '0']  	 w=2 | x=0 | y=0 | z=1626
# add ['y', '25']  	 w=2 | x=0 | y=25 | z=1626
# mul ['y', 'x']  	 w=2 | x=0 | y=0 | z=1626
# add ['y', '1']  	 w=2 | x=0 | y=1 | z=1626
# mul ['z', 'y']  	 w=2 | x=0 | y=1 | z=1626
# mul ['y', '0']  	 w=2 | x=0 | y=0 | z=1626
# add ['y', 'w']  	 w=2 | x=0 | y=2 | z=1626
# add ['y', '1']  	 w=2 | x=0 | y=3 | z=1626
# mul ['y', 'x']  	 w=2 | x=0 | y=0 | z=1626
# add ['z', 'y']  	 w=2 | x=0 | y=0 | z=1626
# inp ['w']  	 w=1 | x=0 | y=0 | z=1626
# mul ['x', '0']  	 w=1 | x=0 | y=0 | z=1626
# add ['x', 'z']  	 w=1 | x=1626 | y=0 | z=1626
# mod ['x', '26']  	 w=1 | x=14 | y=0 | z=1626
# div ['z', '1']  	 w=1 | x=14 | y=0 | z=1626
# add ['x', '13']  	 w=1 | x=27 | y=0 | z=1626
# eql ['x', 'w']  	 w=1 | x=0 | y=0 | z=1626
# eql ['x', '0']  	 w=1 | x=1 | y=0 | z=1626
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=1626
# add ['y', '25']  	 w=1 | x=1 | y=25 | z=1626
# mul ['y', 'x']  	 w=1 | x=1 | y=25 | z=1626
# add ['y', '1']  	 w=1 | x=1 | y=26 | z=1626
# mul ['z', 'y']  	 w=1 | x=1 | y=26 | z=42276
# mul ['y', '0']  	 w=1 | x=1 | y=0 | z=42276
# add ['y', 'w']  	 w=1 | x=1 | y=1 | z=42276
# add ['y', '2']  	 w=1 | x=1 | y=3 | z=42276
# mul ['y', 'x']  	 w=1 | x=1 | y=3 | z=42276
# add ['z', 'y']  	 w=1 | x=1 | y=3 | z=42279
# inp ['w']  	 w=3 | x=1 | y=3 | z=42279
# mul ['x', '0']  	 w=3 | x=0 | y=3 | z=42279
# add ['x', 'z']  	 w=3 | x=42279 | y=3 | z=42279
# mod ['x', '26']  	 w=3 | x=3 | y=3 | z=42279
# div ['z', '26']  	 w=3 | x=3 | y=3 | z=1626
# add ['x', '0']  	 w=3 | x=3 | y=3 | z=1626
# eql ['x', 'w']  	 w=3 | x=1 | y=3 | z=1626
# eql ['x', '0']  	 w=3 | x=0 | y=3 | z=1626
# mul ['y', '0']  	 w=3 | x=0 | y=0 | z=1626
# add ['y', '25']  	 w=3 | x=0 | y=25 | z=1626
# mul ['y', 'x']  	 w=3 | x=0 | y=0 | z=1626
# add ['y', '1']  	 w=3 | x=0 | y=1 | z=1626
# mul ['z', 'y']  	 w=3 | x=0 | y=1 | z=1626
# mul ['y', '0']  	 w=3 | x=0 | y=0 | z=1626
# add ['y', 'w']  	 w=3 | x=0 | y=3 | z=1626
# add ['y', '7']  	 w=3 | x=0 | y=10 | z=1626
# mul ['y', 'x']  	 w=3 | x=0 | y=0 | z=1626
# add ['z', 'y']  	 w=3 | x=0 | y=0 | z=1626
# inp ['w']  	 w=9 | x=0 | y=0 | z=1626
# mul ['x', '0']  	 w=9 | x=0 | y=0 | z=1626
# add ['x', 'z']  	 w=9 | x=1626 | y=0 | z=1626
# mod ['x', '26']  	 w=9 | x=14 | y=0 | z=1626
# div ['z', '26']  	 w=9 | x=14 | y=0 | z=62
# add ['x', '-5']  	 w=9 | x=9 | y=0 | z=62
# eql ['x', 'w']  	 w=9 | x=1 | y=0 | z=62
# eql ['x', '0']  	 w=9 | x=0 | y=0 | z=62
# mul ['y', '0']  	 w=9 | x=0 | y=0 | z=62
# add ['y', '25']  	 w=9 | x=0 | y=25 | z=62
# mul ['y', 'x']  	 w=9 | x=0 | y=0 | z=62
# add ['y', '1']  	 w=9 | x=0 | y=1 | z=62
# mul ['z', 'y']  	 w=9 | x=0 | y=1 | z=62
# mul ['y', '0']  	 w=9 | x=0 | y=0 | z=62
# add ['y', 'w']  	 w=9 | x=0 | y=9 | z=62
# add ['y', '5']  	 w=9 | x=0 | y=14 | z=62
# mul ['y', 'x']  	 w=9 | x=0 | y=0 | z=62
# add ['z', 'y']  	 w=9 | x=0 | y=0 | z=62
# inp ['w']  	 w=1 | x=0 | y=0 | z=62
# mul ['x', '0']  	 w=1 | x=0 | y=0 | z=62
# add ['x', 'z']  	 w=1 | x=62 | y=0 | z=62
# mod ['x', '26']  	 w=1 | x=10 | y=0 | z=62
# div ['z', '26']  	 w=1 | x=10 | y=0 | z=2
# add ['x', '-9']  	 w=1 | x=1 | y=0 | z=2
# eql ['x', 'w']  	 w=1 | x=1 | y=0 | z=2
# eql ['x', '0']  	 w=1 | x=0 | y=0 | z=2
# mul ['y', '0']  	 w=1 | x=0 | y=0 | z=2
# add ['y', '25']  	 w=1 | x=0 | y=25 | z=2
# mul ['y', 'x']  	 w=1 | x=0 | y=0 | z=2
# add ['y', '1']  	 w=1 | x=0 | y=1 | z=2
# mul ['z', 'y']  	 w=1 | x=0 | y=1 | z=2
# mul ['y', '0']  	 w=1 | x=0 | y=0 | z=2
# add ['y', 'w']  	 w=1 | x=0 | y=1 | z=2
# add ['y', '8']  	 w=1 | x=0 | y=9 | z=2
# mul ['y', 'x']  	 w=1 | x=0 | y=0 | z=2
# add ['z', 'y']  	 w=1 | x=0 | y=0 | z=2
# inp ['w']  	 w=1 | x=0 | y=0 | z=2
# mul ['x', '0']  	 w=1 | x=0 | y=0 | z=2
# add ['x', 'z']  	 w=1 | x=2 | y=0 | z=2
# mod ['x', '26']  	 w=1 | x=2 | y=0 | z=2
# div ['z', '26']  	 w=1 | x=2 | y=0 | z=0
# add ['x', '-1']  	 w=1 | x=1 | y=0 | z=0
# eql ['x', 'w']  	 w=1 | x=1 | y=0 | z=0
# eql ['x', '0']  	 w=1 | x=0 | y=0 | z=0
# mul ['y', '0']  	 w=1 | x=0 | y=0 | z=0
# add ['y', '25']  	 w=1 | x=0 | y=25 | z=0
# mul ['y', 'x']  	 w=1 | x=0 | y=0 | z=0
# add ['y', '1']  	 w=1 | x=0 | y=1 | z=0
# mul ['z', 'y']  	 w=1 | x=0 | y=1 | z=0
# mul ['y', '0']  	 w=1 | x=0 | y=0 | z=0
# add ['y', 'w']  	 w=1 | x=0 | y=1 | z=0
# add ['y', '15']  	 w=1 | x=0 | y=16 | z=0
# mul ['y', 'x']  	 w=1 | x=0 | y=0 | z=0
# add ['z', 'y']  	 w=1 | x=0 | y=0 | z=0
# w=1 | x=0 | y=0 | z=0

# %%
2929615277 // 26
# Out:
# 112677510

# %%
27 % 26
# Out:
# 1

# %%
print (monad)
print ("".join([str(m) for m in monad]))
# Out:
# (2, 7, 1, 4, 1, 1, 9, 1, 2, 1, 3, 9, 1, 1)
# 27141191213911

# %%
puzzle.answer_b = ("".join([str(m) for m in monad]))
# Out:
# That's the right answer!  You are one gold star closer to finding the sleigh keys.You have completed Day 24! You can [Shareon
#   Twitter
# Mastodon] this victory or [Return to Your Advent Calendar].

# %%
# decompilation
# section 1:
d = (2, 7, 1, 4, 1, 1, 9, 1, 2, 1, 3, 9, 1, 1)

z = d[0]  
# section 2:
z = z * 26 + d[1]+3        
# section 3:
z = (z) * 26 + d[2] + 8
#section 4
if (d[2] + 3) == d[3]:
    z = z // 26
else: 
    z = (z // 26) * 26 + 5
#section 5
# print(z%26)
z = z * 26 + d[4] + 13
#section 6
z = z * 26 + d[5] + 9
# section 7
z = z * 26 + d[6] + 6
# x = d[6] - 8
if (d[6] - 8) == d[7]:
    z = z // 26
    
#section 8
if (d[5] + 1) == d[8]:
    z = z // 26
# section 9
z = z * 26 + d[9] + 2
# section 10
if (d[9] + 2) == d[10]:
    z = z // 26
# section 11
if (d[4] + 8) == d[11]:
    z = z // 26
else:
    z = (z // 26) * 26 + d[11] + 5
# section 12
# print(z%26)
if (d[1]-6) == d[12]:
    z = z // 26
# section 13
if (d[0] - 1) == d[13]:
    z = z // 13
print(z)
# Out:
# 0

# %%
# needed relations
# d[0] + 1 == d[13]
# d[1] - 6 == d[12]
# d[2] + 3 == d[3]
# d[6] - 8 == d[7]
# d[5] + 1 == d[8]
# d[9] + 2 == d[10]
# d[4] + 8 == d[11]
# Out:
# 8

# %%
import numpy as np

# %%
np.base_repr(42279, base=26)
# Out:
# '2AE3'
