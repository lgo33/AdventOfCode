# %%
#

# %%
import md5

# %%
inp = "yzbqklnj"

# %%
md5.md5("abcdef{!s}".format(609043)).hexdigest()[:5] == '00000'
# Out:
# True

# %%
i = 0
hash = ""
while hash[:6] != '000000':
    i += 1
    hash = md5.md5("{}{!s}".format(inp, i)).hexdigest()    
    if i % 10000 == 0:
        print i, hash
    
print i, hash
# Out:
# 10000 53cf85ae0701a79815109739b3c5c72b
# 20000 fb3a0966e3f384889eef1e0e24502913
# 30000 dd353bc11c54738f029675021997adc4
# 40000 88f7ce9cf43f5bbece25a2cf42a9e8cd
# 50000 c3c96754709a6a08610d276fe8f0dbc6
# 60000 722b2090a17f397820102df34fdfcfcc
# 70000 5b4f8b1faca0c8476921de6a95084146
# 80000 e21203911625332e140a90060530fbd0
# 90000 c3c35bdcec8d88d7b30ba482a1fb3908
# 100000 2a0a325103412ed5924ad8de477f2b0f
# 110000 2f3959750ba6ad77b73a2749a00c8744
# 120000 6c9c902c44c9e3388da3845694e687b3
# 130000 97325d90f84ed4c21dd43839916e6081
# 140000 874198d6f74ca8de88e4ca1f6d5598f3
# 150000 89b90a22379a81a21445f06a8007e7b7
# 160000 04db119f5700a1a2452f40ea00cb2491
# 170000 276d6433ebd47c92bac1fb20beddeea9
# 180000 03a0b5b2b0638e05157e787513013dc7
# 190000 700461ad9b9fc23db95964390ac93ecd
# 200000 3e239a398e29d3a90b07f6c8de01fead
# 210000 c02f2c58918b656f61b47c5e85650266
# 220000 816fd203117e09351740c2b8abacc245
# 230000 fc5af794494cbf02a51dc33d1a86a944
# 240000 e91ec2d41b97523b3389e0f0e0e36bfb
# ...

# %%
type("str") == str
# Out:
# True
