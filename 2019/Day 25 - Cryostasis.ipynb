# %%
with open('./data/input_25.txt') as fh:
    file_input = fh.read().strip()
mem = [int(d) for d in file_input.split(',')]

# %%
from intcode import intcode

# %%
ic = intcode(mem, add_mem=10000, take_input=lambda: _inp.pop(0), give_output=lambda x: print(chr(x), end=''))

# %%
rc = 0
ic.reset()
_inp = [ord(i) for i in _start_inp]

while rc!=99:
    rc = ic.run()
    tmp = input()
    print(tmp)
    if tmp == 'q':
        break
    _inp += [ord(c) for c in tmp] + [10]
# Out:
# == Hull Breach ==
# You got in through a hole in the floor here. To keep your ship from also freezing, the hole has been sealed.
#
# Doors here lead:
# - north
# - east
# - south
#
# Command?
#
#
#
# == Engineering ==
# You see a whiteboard with plans for Springdroid v2.
#
# Doors here lead:
# - east
# - south
# - west
#
# Items here:
# - escape pod
#
# Command?
#
#
#
# == Navigation ==
# Status: Stranded. Please supply measurements from fifty stars to recalibrate.
#
# Doors here lead:
# - east
# - west
#
# Items here:
# - coin
#
# Command?
#
# You take the coin.
#
# Command?
#
#
#
# == Engineering ==
# You see a whiteboard with plans for Springdroid v2.
#
# Doors here lead:
# - east
# - south
# - west
#
# Items here:
# - escape pod
#
# Command?
#
#
#
# == Hull Breach ==
# You got in through a hole in the floor here. To keep your ship from also freezing, the hole has been sealed.
#
# Doors here lead:
# - north
# - east
# - south
#
# Command?
#
#
#
# == Arcade ==
# ...

# %%
# too heavy
cake
coin
sand

# too light
wm + astrolabe + food ration 
# all together too light
ornament + jam + astrolabe + food ration

passt: wm +astrolabe + food ration + ornament
# Out:
#   File "<ipython-input-7-57202eb242f5>", line 9
#     food ration
#               ^
# SyntaxError: invalid syntax

# %%
_start_inp = """north
east
take coin
west
south
south
west
take sand
north
north
east
take astrolabe
west
south
south
east
take food ration
north
east
take cake
south
take weather machine
west
take ornament
west
take jam
east
east
north
east
east
east
drop coin
drop sand
drop cake
drop jam
south
"""

# %%
# starting south:
# Items in your inventory:
# - sand
# - astrolabe
# - food ration
# Out:
#  abc

# %%
# cake too heavy
# weather machine too light
# Out:
# [97, 98, 99]

# %%
# checkpoint all east one south
